# %%
import Plasmon_Modeling as PM
import matplotlib.pyplot as plt

# %%
sample = PM.RectangularSample(50,50)

# %%
sample.placeCircularReflector(20,20,5)

# %%
sample.placeCircularSource(40,40,2)

# %%
mesh = sample.getMesh()

# %%
sigma = PM.S()
omega = PM.O()
sigma.set_sigma_values(1,10)
omega.set_omega_values(1,1)

#running the simulation
solution = sample.run(omega,sigma,density = 200,to_plot=True)
awa = sample.cast_solution_to_AWA()

real_part = awa[0].T
im_part = awa[1].T
# Out:
# Attempting to solve:

# %%
plt.imshow(real_part);plt.colorbar()

# %%
temp = sample.cast_solution_to_Array()

# %%
plt.imshow(temp[0],cmap='seismic')

# %%
plt.imshow(temp[1]-temp[0])

# %%
import Toolbox as T

# %%
real =solution.split(deepcopy=True)[0]

# %%
T.fenics_func_to_AWA(real,mesh)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-36-83cc7ea5fe1b> in <module>
# ----> 1 T.fenics_func_to_AWA(real,mesh)
#
# ~/Desktop/BokehPlasmon/Toolbox.py in fenics_func_to_AWA(input_function, input_mesh)
#      25     # u1 = interpolate(Pv.split(deepcopy=True)[1], V2)
#      26
# ---> 27     BF0 = FT.BoxField2(u0)
#      28     # BF1 = FT.BoxField2(u1)
#      29
#
# ~/Desktop/Fenics/FenicsTools/__init__.py in __init__(self, fenics_function, uniform_mesh, **kwargs)
#     561
#     562         fenics_mesh=fenics_function.function_space().mesh()
# --> 563         division=get_regular_mesh_size(fenics_mesh)
#     564
#     565         #only novel thing the constructor does is to build the grid
#
# ~/Desktop/Fenics/FenicsTools/__init__.py in get_regular_mesh_size(fenics_mesh)
#     260     shape=[len(coord_vals) for coord_vals in coords_vals]
#     261
# ...

# %%
casted = T.process_fenics_function(mesh, real, x_axis=np.linspace(0,50,200), y_axis=np.linspace(0,50,200)[::-1]).data
